# %%
from flask import Flask, render_template, request, jsonify
from flask_cors import CORS, cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
searchstring='grocery'

# %%
flipkart_url='https://www.flipkart.com/search?q=' + searchstring

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=grocery'

# %%
uclient = uReq(flipkart_url)

# %%
uclient

# %%
flipkartpage=uclient.read()

# %%
flipkartpage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.f9cc90.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.f32dbb.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Fli
# ...

# %%
flipkart_html=bs(flipkartpage,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
links=flipkart_html.findAll('a',attrs={'class':'VJA3rP'})

# %%
link=links[0].get('href')

# %%
link
# Out:
# '/tata-coffee-gold-instant/p/itm9c29d07d33d5f?pid=CFEGCXN8TTAFZE6G&lid=LSTCFEGCXN8TTAFZE6GSGRTTQ&marketplace=FLIPKART&q=grocery&store=eat&srno=s_1_1&otracker=search&fm=organic&iid=en_QOldEGv6PMuneSw5PWZrFuFafyEaX0q77qgV1Y-XEPMsj-yetsPzyDBrk1cmZ76409aN9nlDf3-SBFHXn7cqtE4IsYyWu-Pj9cxFjFAoaLk%3D&ppt=None&ppn=None&ssid=nxe97jjlcw0000001723548364965&qH=130fd2da72540534'

# %%
product_link='https://www.flipkart.com' + link

# %%
product_link
# Out:
# 'https://www.flipkart.com/tata-coffee-gold-instant/p/itm9c29d07d33d5f?pid=CFEGCXN8TTAFZE6G&lid=LSTCFEGCXN8TTAFZE6GSGRTTQ&marketplace=FLIPKART&q=grocery&store=eat&srno=s_1_1&otracker=search&fm=organic&iid=en_QOldEGv6PMuneSw5PWZrFuFafyEaX0q77qgV1Y-XEPMsj-yetsPzyDBrk1cmZ76409aN9nlDf3-SBFHXn7cqtE4IsYyWu-Pj9cxFjFAoaLk%3D&ppt=None&ppn=None&ssid=nxe97jjlcw0000001723548364965&qH=130fd2da72540534'

# %%
new_link=uReq(product_link)

# %%
new_link

# %%
URL=bs(new_link,'html.parser')

# %%
URL
# Out:
# <!DOCTYPE html>
# ...

# %%
#customer rating
comment=URL.find_all('div', {'class': "RcXBOT"})

# %%
len(comment)
# Out:
# 11

# %%
for i in comment:
    print(i.div.div.div.div.text)
# Out:
# 4
# 5
# 4
# 4
# 3
# 5
# 3
# 4
# 4
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 2
#       1 for i in comment:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment[1].div.find_all('div',{'class':"ZmyHeo"})
# Out:
# [<div class="ZmyHeo"><div><div class="">TATA is always best. Close your eyes,go for it. If Tata Group close their Eyes, India will be blind.</div><span class="wTYmpv"><span>READ MORE</span></span></div></div>]

# %%
#customer comments
for i in comment:
    print(i.div.find_all('div',{'class':"ZmyHeo"})[0].div.text)
    print('\n')
# Out:
# Tata is a trusted brand and one can go for it. I bbought this for the second time and the taste is awesome. Though I love the taste of nescafe gold more than this, but the price of nescafe gold is very high.READ MORE
#
#
# TATA is always best. Close your eyes,go for it. If Tata Group close their Eyes, India will be blind.READ MORE
#
#
# very good testREAD MORE
#
#
# SuperREAD MORE
#
#
# Different taste than nescafe gold . Nescafe gold is recommended over this .Sorry tata .READ MORE
#
#
# Good tasteREAD MORE
#
#
# Expected better quality from the brand like TATA. Not even close to Nescafe gold or Davidoff rich aromaREAD MORE
#
#
# NiceREAD MORE
#
#
# Better and cheaper than roge and vanalaya coffeeREAD MORE
#
#
# Very goodREAD MORE
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 3
#       1 #customer comments
#       2 for i in comment:
# ...

# %%
comment[2].div.find_all('p',{'class':"_2NsDsF AwS1CA"})[0].text
# Out:
# 'Ravi Sonker'

# %%
#customer name

for i in comment:
   print(i.div.div.find_all('p',{'class':"_2NsDsF AwS1CA"})[0].text)
   print('\n')
# Out:
# Hitu.....
#
#
# Shankhadip Sarkar
#
#
# Ravi Sonker
#
#
# Dr Sudarshan  Ashok
#
#
# Vimlesh Kumar
#
#
# Dheeraj Kumar
#
#
# Flipkart Customer
#
#
# Patel Viraj
#
#
# Om prakash Rajpurohit
#
#
# Dr Sudarshan  Ashok
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 4
#       1 #customer name
#       3 for i in comment:
# ----> 4    print(i.div.div.find_all('p',{'class':"_2NsDsF AwS1CA"})[0].text)
#       5    print('\n')
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#customer question
question=URL.find_all('div' , {'class':"BZMA+t"})

# %%
len(question)
# Out:
# 9

# %%
for i in question:
    print(i.div.find_all('div',{'class':'wys2hv _43gOsC'})[0].text)
    print('\n')
# Out:
# Q:Does it have caffeine?
#
#
# Q:Is it block coffee
#
#
# Q:How make it
#
#
# Q:Continental Xtra vs Tata Gold coffee? Which one is good
#
#
# Q:Is this decaffinated?
#
#
# Q:is it strong
#
#
# Q:How to use in coffee
#
#
# Q:Is it can be used as a black coffee
#
#
# Q:We have blend after puchasing?  or this is blended??
